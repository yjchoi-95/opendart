# %% [markdown]
# ## Import

# %%
import OpenDartReader
import pandas as pd
import numpy as np

# %% [markdown]
# * dart setting

# %%
api_key = '1b39652cef07f626c9d37375edf582ee51b1407f'
dart = OpenDartReader(api_key)
# Out:
# C:\Windows\Anaconda3\lib\site-packages\urllib3\connectionpool.py:1095: InsecureRequestWarning: Unverified HTTPS request is being made to host 'opendart.fss.or.kr'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(

# %%
df = dart.regstate('쏘카', '지분증권')
# Out:
# C:\Windows\Anaconda3\lib\site-packages\urllib3\connectionpool.py:1095: InsecureRequestWarning: Unverified HTTPS request is being made to host 'opendart.fss.or.kr'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(

# %%
df.iloc[:, :18]
# Out:
#          rcept_no corp_cls corp_code corp_name                            sbd  \
# 0  20220715000095        Y  01026157        쏘카  2022년 08월 10일 ~ 2022년 08월 11일
# 0  20220715000095        Y  01026157        쏘카                            NaN
# 0  20220715000095        Y  01026157        쏘카                            NaN
# 1  20220715000095        Y  01026157        쏘카                            NaN
# 2  20220715000095        Y  01026157        쏘카                            NaN
# 0  20220715000095        Y  01026157        쏘카                            NaN
# 1  20220715000095        Y  01026157        쏘카                            NaN
# 2  20220715000095        Y  01026157        쏘카                            NaN
# 0  20220715000095        Y  01026157        쏘카                            NaN
# 0  20220715000095        Y  01026157        쏘카                            NaN
#
#             pymd          sband          asand asstd exstk exprc expd  \
# ...

# %%
df.iloc[:, 18:]
# Out:
#               slta slmthn actsen  actnmn     udtcnt           udtamt  \
# 0              NaN    NaN    NaN     NaN        NaN              NaN
# 0  154,700,000,000   일반공모    NaN     NaN        NaN              NaN
# 0              NaN    NaN     대표  미래에셋증권  3,162,250  107,516,500,000
# 1              NaN    NaN     공동    삼성증권  1,342,250   45,636,500,000
# 2              NaN    NaN     인수   유안타증권     45,500    1,547,000,000
# 0              NaN    NaN    NaN     NaN        NaN              NaN
# 1              NaN    NaN    NaN     NaN        NaN              NaN
# 2              NaN    NaN    NaN     NaN        NaN              NaN
# 0              NaN    NaN    NaN     NaN        NaN              NaN
# 0              NaN    NaN    NaN     NaN        NaN              NaN
#
#           udtprc udtmth       se     amt  hdr rl_cmp bfsl_hdstk slstk  \
# 0            NaN    NaN      NaN     NaN  NaN    NaN        NaN   NaN
# ...
